# %%
import pandas as pd
from ML.separation_escalation import load_data, split_data, scale_data
import numpy as np

# %%
# 1. Carregar os dados
df_clean = load_data()

# 2. Dividir os dados
X_train, X_test, y_train, y_test = split_data(df_clean)

# 3. Escalonar
X_train_scaled, X_test_scaled, scaler_trained = scale_data(X_train, X_test)
